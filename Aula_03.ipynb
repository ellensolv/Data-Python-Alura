# %% [markdown]
# <a href="https://colab.research.google.com/github/ellensolv/Data-Python-Alura/blob/main/Aula_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

# %%
df_principal = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="Principal")
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20         11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40          2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19          7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04          2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03          2.49         -3.66
# ..    ...        ...          ...           ...           ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45         -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70         -2.46         -6.95        -23.55
# 78  RENT3 2024-01-26        56.24         -3.63         -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07         -4.36         -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92         -8.07        -15.91        -34.00
#
#     Var. Ano (%)  Var. 12M (%)  Var. Mín (%)  Var. Máx (%)  ...  Variação $.2  \
# 0           2.26         15.97          9.18          9.56  ...  1.081515e+08
# 1         -12.11         50.56          6.66          6.86  ... -1.043592e+09
# 2           7.64         77.55         40.81         42.34  ...  7.087773e+09
# 3          -4.89         18.85         51.89         53.17  ... -1.859212e+09
# 4          -3.66         20.70         36.37         37.32  ... -2.645988e+08
# ..           ...           ...           ...           ...  ...           ...
# 76        -13.98        -32.72         10.70         11.08  ... -9.294602e+08
# 77        -23.55        -85.74          8.67          8.95  ... -2.541781e+08
# 78        -11.57         -2.77         56.04         58.90  ... -6.278141e+09
# 79        -12.29        -36.83          3.05          3.23  ... -2.260905e+08
# 80        -34.00        -25.44          5.51          6.02  ... -6.044039e+08
#
#     RESULTADO.1  Var. Ano (%).1  Valor Inicial   Variação $.3 RESULTADO.2  \
# 0         Subiu          0.0226        9.290045  1.081515e+08       Subiu
# 1        Desceu         -0.1211        7.759700 -1.043592e+09      Desceu
# 2         Subiu          0.0764       38.981791  7.087773e+09       Subiu
# 3        Desceu         -0.0489       55.630323 -1.859212e+09      Desceu
# 4        Desceu         -0.0366       38.509446 -2.645988e+08      Desceu
# ..          ...             ...             ...           ...         ...
# 76       Desceu         -0.1398       12.450593 -9.294602e+08      Desceu
# 77       Desceu         -0.2355       11.379987 -2.541781e+08      Desceu
# 78       Desceu         -0.1157       63.598326 -6.278141e+09      Desceu
# 79       Desceu         -0.1229        3.500171 -2.260905e+08      Desceu
# 80       Desceu         -0.3400        8.969697 -6.044039e+08      Desceu
#
#    Var. 12M Valor Inicial.2  Variação $.4 RESULTADO.3
# 0    0.1597        8.191774  6.738901e+08       Subiu
# 1    0.5056        4.529756  2.543452e+09       Subiu
# 2    0.7755       23.632780  4.361654e+10       Subiu
# 3    0.1885       44.518300  5.735331e+09       Subiu
# 4    0.2070       30.737365  1.194474e+09       Subiu
# ..      ...             ...           ...         ...
# 76  -0.3272       15.918549 -2.781316e+09      Desceu
# 77  -0.8574       61.009818 -4.961222e+09      Desceu
# 78  -0.0277       57.842230 -1.367026e+09      Desceu
# 79  -0.3683        4.859902 -9.407416e+08      Desceu
# 80  -0.2544        7.939914 -4.003165e+08      Desceu
#
# [81 rows x 36 columns]

# %%
df_total_acoes = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="Total_de_acoes")
df_total_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_ticker = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="Ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_chatgpt = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="GPT")
df_chatgpt
# Out:
#      Nome da empresa           Segmento  Idade (anos)
# 0           Usiminas         Siderurgia            60
# 1      CSN Mineração          Mineração             8
# 2          Petrobras           Petróleo            69
# 3             Suzano   Papel e Celulose            94
# 4       CPFL Energia            Energia           109
# ..               ...                ...           ...
# 76  Carrefour Brasil             Varejo            37
# 77       Casas Bahia             Varejo            95
# 78          Localiza  Aluguel de Carros            49
# 79               CVC            Turismo            50
# 80               GOL            Aviação            20
#
# [81 rows x 3 columns]

# %%
df_principal = df_principal[['Ativo', 'Data', 'Último (R$)', 'Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_principal = df_principal.rename(columns={'Último (R$)':'valor_final', 'Var. Dia (%)':'var_dia_pct'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3 2024-01-26        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
df_principal['Var_pct'] = df_principal['var_dia_pct'] / 100
df_principal['valor_inicial'] = df_principal['valor_final'] / (df_principal['Var_pct'] + 1)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
# [81 rows x 6 columns]

# %%
df_principal = df_principal.merge(df_total_acoes, left_on='Ativo', right_on='Código', how='left')
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682  GOLL4
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.drop(columns=['Código'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 7 columns]

# %%
df_principal['Variacao_rs'] = (df_principal['valor_final'] - df_principal['valor_inicial'])*df_principal['Qtde. Teórica']
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica   Variacao_rs
# 0    5.151174e+08  2.418897e+08
# 1    1.110559e+09  1.775160e+08
# 2    2.379878e+09  2.140059e+09
# 3    6.834528e+08  7.229463e+08
# 4    1.877325e+08  1.385740e+08
# ..            ...           ...
# 76   5.339906e+08 -1.436355e+08
# 77   9.484305e+07 -2.081024e+07
# 78   8.532023e+08 -1.807433e+09
# 79   5.255828e+08 -7.355741e+07
# 80   1.981849e+08 -1.029932e+08
#
# [81 rows x 8 columns]

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df_principal['Qtde. Teórica'] = df_principal['Qtde. Teórica'].astype(int)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica   Variacao_rs
# 0       515117391  2.418897e+08
# 1      1110559345  1.775160e+08
# 2      2379877655  2.140059e+09
# 3       683452836  7.229463e+08
# 4       187732538  1.385740e+08
# ..            ...           ...
# 76      533990587 -1.436355e+08
# 77       94843047 -2.081024e+07
# 78      853202347 -1.807433e+09
# 79      525582771 -7.355741e+07
# 80      198184909 -1.029932e+08
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica':'Qtd_teorica'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtd_teorica   Variacao_rs
# 0     515117391  2.418897e+08
# 1    1110559345  1.775160e+08
# 2    2379877655  2.140059e+09
# 3     683452836  7.229463e+08
# 4     187732538  1.385740e+08
# ..          ...           ...
# 76    533990587 -1.436355e+08
# 77     94843047 -2.081024e+07
# 78    853202347 -1.807433e+09
# 79    525582771 -7.355741e+07
# 80    198184909 -1.029932e+08
#
# [81 rows x 8 columns]

# %%
df_principal['Resultado'] = df_principal['Variacao_rs'].apply(lambda x: 'Subiu' if x > 0 else ('Desceu' if x < 0 else 'Estável'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtd_teorica   Variacao_rs Resultado
# 0     515117391  2.418897e+08     Subiu
# 1    1110559345  1.775160e+08     Subiu
# 2    2379877655  2.140059e+09     Subiu
# 3     683452836  7.229463e+08     Subiu
# 4     187732538  1.385740e+08     Subiu
# ..          ...           ...       ...
# 76    533990587 -1.436355e+08    Desceu
# 77     94843047 -2.081024e+07    Desceu
# 78    853202347 -1.807433e+09    Desceu
# 79    525582771 -7.355741e+07    Desceu
# 80    198184909 -1.029932e+08    Desceu
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.merge(df_ticker, left_on='Ativo', right_on='Ticker', how='left')
df_principal = df_principal.drop(columns=['Ticker'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtd_teorica   Variacao_rs Resultado              Nome
# 0     515117391  2.418897e+08     Subiu          Usiminas
# 1    1110559345  1.775160e+08     Subiu     CSN Mineração
# 2    2379877655  2.140059e+09     Subiu         Petrobras
# 3     683452836  7.229463e+08     Subiu            Suzano
# 4     187732538  1.385740e+08     Subiu      CPFL Energia
# ..          ...           ...       ...               ...
# 76    533990587 -1.436355e+08    Desceu  Carrefour Brasil
# 77     94843047 -2.081024e+07    Desceu       Casas Bahia
# 78    853202347 -1.807433e+09    Desceu          Localiza
# 79    525582771 -7.355741e+07    Desceu               CVC
# 80    198184909 -1.029932e+08    Desceu               GOL
#
# [81 rows x 10 columns]

# %%
df_principal = df_principal.merge(df_chatgpt, left_on='Nome', right_on='Nome da empresa', how='left')
df_principal = df_principal.drop(columns=['Nome da empresa'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 4   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# ..    ...        ...          ...          ...      ...            ...
# 82  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 83  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 84  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 85  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 86  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtd_teorica   Variacao_rs Resultado              Nome           Segmento  \
# 0     515117391  2.418897e+08     Subiu          Usiminas         Siderurgia
# 1    1110559345  1.775160e+08     Subiu     CSN Mineração          Mineração
# 2    2379877655  2.140059e+09     Subiu         Petrobras           Petróleo
# 3    2379877655  2.140059e+09     Subiu         Petrobras           Petróleo
# 4     683452836  7.229463e+08     Subiu            Suzano   Papel e Celulose
# ..          ...           ...       ...               ...                ...
# 82    533990587 -1.436355e+08    Desceu  Carrefour Brasil             Varejo
# 83     94843047 -2.081024e+07    Desceu       Casas Bahia             Varejo
# 84    853202347 -1.807433e+09    Desceu          Localiza  Aluguel de Carros
# 85    525582771 -7.355741e+07    Desceu               CVC            Turismo
# 86    198184909 -1.029932e+08    Desceu               GOL            Aviação
#
#     Idade (anos)
# 0             60
# 1              8
# 2             69
# 3             69
# 4             94
# ..           ...
# 82            37
# 83            95
# 84            49
# 85            50
# 86            20
#
# [87 rows x 12 columns]

# %%
df_principal = df_principal.rename(columns={'Idade (fundação ou início de operações)':'Idade'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 4   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# ..    ...        ...          ...          ...      ...            ...
# 82  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 83  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 84  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 85  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 86  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtd_teorica   Variacao_rs Resultado              Nome           Segmento  \
# 0     515117391  2.418897e+08     Subiu          Usiminas         Siderurgia
# 1    1110559345  1.775160e+08     Subiu     CSN Mineração          Mineração
# 2    2379877655  2.140059e+09     Subiu         Petrobras           Petróleo
# 3    2379877655  2.140059e+09     Subiu         Petrobras           Petróleo
# 4     683452836  7.229463e+08     Subiu            Suzano   Papel e Celulose
# ..          ...           ...       ...               ...                ...
# 82    533990587 -1.436355e+08    Desceu  Carrefour Brasil             Varejo
# 83     94843047 -2.081024e+07    Desceu       Casas Bahia             Varejo
# 84    853202347 -1.807433e+09    Desceu          Localiza  Aluguel de Carros
# 85    525582771 -7.355741e+07    Desceu               CVC            Turismo
# 86    198184909 -1.029932e+08    Desceu               GOL            Aviação
#
#     Idade (anos)
# 0             60
# 1              8
# 2             69
# 3             69
# 4             94
# ..           ...
# 82            37
# 83            95
# 84            49
# 85            50
# 86            20
#
# [87 rows x 12 columns]

# %%
df_principal = df_principal.rename(columns={'Idade (anos)':'Ano_de_fundacao'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 4   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# ..    ...        ...          ...          ...      ...            ...
# 82  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 83  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 84  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 85  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 86  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtd_teorica   Variacao_rs Resultado              Nome           Segmento  \
# 0     515117391  2.418897e+08     Subiu          Usiminas         Siderurgia
# 1    1110559345  1.775160e+08     Subiu     CSN Mineração          Mineração
# 2    2379877655  2.140059e+09     Subiu         Petrobras           Petróleo
# 3    2379877655  2.140059e+09     Subiu         Petrobras           Petróleo
# 4     683452836  7.229463e+08     Subiu            Suzano   Papel e Celulose
# ..          ...           ...       ...               ...                ...
# 82    533990587 -1.436355e+08    Desceu  Carrefour Brasil             Varejo
# 83     94843047 -2.081024e+07    Desceu       Casas Bahia             Varejo
# 84    853202347 -1.807433e+09    Desceu          Localiza  Aluguel de Carros
# 85    525582771 -7.355741e+07    Desceu               CVC            Turismo
# 86    198184909 -1.029932e+08    Desceu               GOL            Aviação
#
#     Ano_de_fundacao
# 0                60
# 1                 8
# 2                69
# 3                69
# 4                94
# ..              ...
# 82               37
# 83               95
# 84               49
# 85               50
# 86               20
#
# [87 rows x 12 columns]

# %%
df_principal['Cat_idade'] = df_principal['Ano_de_fundacao'].apply(lambda x: 'Mais de 100' if x > 100 else ('Menos de 50' if x < 50 else 'Entre 50 e 100'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 4   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# ..    ...        ...          ...          ...      ...            ...
# 82  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 83  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 84  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 85  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 86  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtd_teorica   Variacao_rs Resultado              Nome           Segmento  \
# 0     515117391  2.418897e+08     Subiu          Usiminas         Siderurgia
# 1    1110559345  1.775160e+08     Subiu     CSN Mineração          Mineração
# 2    2379877655  2.140059e+09     Subiu         Petrobras           Petróleo
# 3    2379877655  2.140059e+09     Subiu         Petrobras           Petróleo
# 4     683452836  7.229463e+08     Subiu            Suzano   Papel e Celulose
# ..          ...           ...       ...               ...                ...
# 82    533990587 -1.436355e+08    Desceu  Carrefour Brasil             Varejo
# 83     94843047 -2.081024e+07    Desceu       Casas Bahia             Varejo
# 84    853202347 -1.807433e+09    Desceu          Localiza  Aluguel de Carros
# 85    525582771 -7.355741e+07    Desceu               CVC            Turismo
# 86    198184909 -1.029932e+08    Desceu               GOL            Aviação
#
#     Ano_de_fundacao       Cat_idade
# 0                60  Entre 50 e 100
# 1                 8     Menos de 50
# 2                69  Entre 50 e 100
# 3                69  Entre 50 e 100
# 4                94  Entre 50 e 100
# ..              ...             ...
# 82               37     Menos de 50
# 83               95  Entre 50 e 100
# 84               49     Menos de 50
# 85               50  Entre 50 e 100
# 86               20     Menos de 50
#
# [87 rows x 13 columns]

# %%
# Calculando o maior valor
maior = df_principal['Variacao_rs'].max()

# Calculando o menor valor
menor = df_principal['Variacao_rs'].min()

# Calculando a média
media = df_principal['Variacao_rs'].mean()

# Calculando a média de quem subiu
media_subiu = df_principal[df_principal['Resultado'] == 'Subiu']['Variacao_rs'].mean()

# Calculando a média de quem desceu
media_desceu = df_principal[df_principal['Resultado'] == 'Desceu']['Variacao_rs'].mean()

# Imprimindo os resultados
print(f"Maior\tR$ {maior:,.2f}")
print(f"Menor\tR$ {menor:,.2f}")
print(f"Média\tR$ {media:,.2f}")
print(f"Média de quem subiu\tR$ {media_subiu:,.2f}")
print(f"Média de quem desceu\tR$ {media_desceu:,.2f}")
# Out:
# Maior	R$ 4,762,926,995.25
# Menor	R$ -1,807,432,634.46
# Média	R$ 218,008,898.33
# Média de quem subiu	R$ 538,720,638.36
# Média de quem desceu	R$ -186,265,310.46

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
df_principal_subiu
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 4   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 5   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# 6   PRIO3 2024-01-26        45.69         1.98   0.0198      44.802903
# 7   PETR4 2024-01-26        39.96         1.73   0.0173      39.280448
# 8   PETR4 2024-01-26        39.96         1.73   0.0173      39.280448
# 9   VALE3 2024-01-26        69.50         1.66   0.0166      68.365139
# 10  MULT3 2024-01-26        28.19         1.58   0.0158      27.751526
# 11  ITUB4 2024-01-26        32.81         1.48   0.0148      32.331494
# 12  RDOR3 2024-01-26        27.56         1.43   0.0143      27.171448
# 13  BRKM5 2024-01-26        18.55         1.42   0.0142      18.290278
# 14  AZUL4 2024-01-26        14.27         1.42   0.0142      14.070203
# 15  RRRP3 2024-01-26        28.75         1.41   0.0141      28.350261
# 16  EQTL3 2024-01-26        35.32         1.34   0.0134      34.852970
# 17  CSNA3 2024-01-26        18.16         1.33   0.0133      17.921642
# 18  YDUQ3 2024-01-26        19.77         1.28   0.0128      19.520142
# 19  UGPA3 2024-01-26        28.31         1.28   0.0128      27.952212
# 20  MRVE3 2024-01-26         8.08         1.25   0.0125       7.980247
# 21  ARZZ3 2024-01-26        57.91         1.15   0.0115      57.251607
# 22  BBDC4 2024-01-26        15.52         1.04   0.0104      15.360253
# 23  BBDC4 2024-01-26        15.52         1.04   0.0104      15.360253
# 24  BEEF3 2024-01-26         7.19         0.98   0.0098       7.120222
# 25  PCAR3 2024-01-26         4.14         0.97   0.0097       4.100228
# 26  BRFS3 2024-01-26        14.61         0.96   0.0096      14.471078
# 27  VIVT3 2024-01-26        51.20         0.88   0.0088      50.753370
# 28  RAIL3 2024-01-26        22.64         0.84   0.0084      22.451408
# 29  CIEL3 2024-01-26         4.90         0.82   0.0082       4.860147
# 30  DXCO3 2024-01-26         7.81         0.77   0.0077       7.750323
# 31  TIMS3 2024-01-26        17.52         0.74   0.0074      17.391304
# 32  BRAP4 2024-01-26        23.22         0.73   0.0073      23.051722
# 33  LWSA3 2024-01-26         5.55         0.72   0.0072       5.510326
# 34  RECV3 2024-01-26        23.83         0.71   0.0071      23.662000
# 35  ITSA4 2024-01-26        10.01         0.70   0.0070       9.940417
# 36  BBAS3 2024-01-26        56.97         0.68   0.0068      56.585221
# 37  RADL3 2024-01-26        26.16         0.61   0.0061      26.001392
# 38  GOAU4 2024-01-26        10.08         0.59   0.0059      10.020877
# 39  CSAN3 2024-01-26        18.57         0.59   0.0059      18.461080
# 40  JBSS3 2024-01-26        24.34         0.57   0.0057      24.202048
# 41  MGLU3 2024-01-26         2.08         0.48   0.0048       2.070064
# 42  BBDC3 2024-01-26        13.75         0.36   0.0036      13.700678
# 43  BBDC3 2024-01-26        13.75         0.36   0.0036      13.700678
# 44  GGBR4 2024-01-26        21.84         0.27   0.0027      21.781191
# 45  RAIZ4 2024-01-26         3.74         0.26   0.0026       3.730301
# 46  CPLE6 2024-01-26        10.07         0.19   0.0019      10.050903
# 47  VAMO3 2024-01-26         8.18         0.12   0.0012       8.170196
#
#     Qtd_teorica   Variacao_rs Resultado                  Nome  \
# 0     515117391  2.418897e+08     Subiu              Usiminas
# 1    1110559345  1.775160e+08     Subiu         CSN Mineração
# 2    2379877655  2.140059e+09     Subiu             Petrobras
# 3    2379877655  2.140059e+09     Subiu             Petrobras
# 4     683452836  7.229463e+08     Subiu                Suzano
# 5     187732538  1.385740e+08     Subiu          CPFL Energia
# 6     800010734  7.096875e+08     Subiu              PetroRio
# 7    4566445852  3.103136e+09     Subiu             Petrobras
# 8    4566445852  3.103136e+09     Subiu             Petrobras
# 9    4196924316  4.762927e+09     Subiu                  Vale
# 10    268505432  1.177327e+08     Subiu             Multiplan
# 11   4801593832  2.297592e+09     Subiu         Itaú Unibanco
# 12   1168230366  4.539179e+08     Subiu             Rede D'Or
# 13    265877867  6.905432e+07     Subiu               Braskem
# 14    327593725  6.545221e+07     Subiu                  Azul
# 15    235665566  9.420464e+07     Subiu          3R Petroleum
# 16   1095587251  5.116719e+08     Subiu    Equatorial Energia
# 17    600865451  1.432210e+08     Subiu  Siderúrgica Nacional
# 18    289347914  7.229584e+07     Subiu                 YDUQS
# 19   1086411192  3.887052e+08     Subiu              Ultrapar
# 20    376187582  3.752587e+07     Subiu                   MRV
# 21     62305891  4.102179e+07     Subiu                Arezzo
# 22   5146576868  8.221483e+08     Subiu        Banco Bradesco
# 23   5146576868  8.221483e+08     Subiu        Banco Bradesco
# 24    261036182  1.821463e+07     Subiu               Minerva
# 25    159430826  6.340916e+06     Subiu   Grupo Pão de Açúcar
# 26   1677525446  2.330458e+08     Subiu                   BRF
# 27    423091712  1.889653e+08     Subiu                  Vivo
# 28   1218352541  2.297713e+08     Subiu                  Rumo
# 29   1095462329  4.365768e+07     Subiu                 Cielo
# 30    302768240  1.806845e+07     Subiu                 Dexco
# 31    807896814  1.039728e+08     Subiu                   TIM
# 32    251003438  4.223825e+07     Subiu             Bradespar
# 33    393173139  1.559889e+07     Subiu               Locaweb
# 34    275005663  4.620101e+07     Subiu        PetroRecôncavo
# 35   5372783971  3.738540e+08     Subiu                Itaúsa
# 36   1420949112  5.467521e+08     Subiu       Banco do Brasil
# 37   1275798515  2.023525e+08     Subiu          RaiaDrogasil
# 38    660411219  3.904561e+07     Subiu    Metalúrgica Gerdau
# 39   1168097881  1.272297e+08     Subiu                 Cosan
# 40   1134986472  1.565733e+08     Subiu                   JBS
# 41   2867627068  2.849362e+07     Subiu        Magazine Luiza
# 42   1500728902  7.401961e+07     Subiu        Banco Bradesco
# 43   1500728902  7.401961e+07     Subiu        Banco Bradesco
# 44   1118525506  6.577961e+07     Subiu                Gerdau
# 45   1193047233  1.157111e+07     Subiu                Raízen
# 46   1679335290  3.206979e+07     Subiu                 Copel
# 47    421383330  4.131341e+06     Subiu           Grupo Vamos
#
#               Segmento  Ano_de_fundacao       Cat_idade
# 0           Siderurgia               60  Entre 50 e 100
# 1            Mineração                8     Menos de 50
# 2             Petróleo               69  Entre 50 e 100
# 3             Petróleo               69  Entre 50 e 100
# 4     Papel e Celulose               94  Entre 50 e 100
# 5              Energia              109     Mais de 100
# 6             Petróleo                9     Menos de 50
# 7             Petróleo               69  Entre 50 e 100
# 8             Petróleo               69  Entre 50 e 100
# 9            Mineração               79  Entre 50 e 100
# 10    Shopping Centers               48     Menos de 50
# 11               Banco               13     Menos de 50
# 12               Saúde               48     Menos de 50
# 13             Química               19     Menos de 50
# 14             Aviação               13     Menos de 50
# 15            Petróleo               10     Menos de 50
# 16             Energia               23     Menos de 50
# 17          Siderurgia               80  Entre 50 e 100
# 18            Educação               59  Entre 50 e 100
# 19             Energia               83  Entre 50 e 100
# 20          Construção               41     Menos de 50
# 21                Moda               50  Entre 50 e 100
# 22               Banco               78  Entre 50 e 100
# 23               Banco               78  Entre 50 e 100
# 24           Alimentos               29     Menos de 50
# 25              Varejo               72  Entre 50 e 100
# 26           Alimentos               11     Menos de 50
# 27    Telecomunicações               18     Menos de 50
# 28           Logística               12     Menos de 50
# 29  Meios de Pagamento               24     Menos de 50
# 30         Imobiliário                8     Menos de 50
# 31    Telecomunicações               25     Menos de 50
# 32             Holding               40     Menos de 50
# 33          Tecnologia               24     Menos de 50
# 34            Petróleo               11     Menos de 50
# 35             Holding               54  Entre 50 e 100
# 36               Banco              213     Mais de 100
# 37              Varejo              117     Mais de 100
# 38          Siderurgia              121     Mais de 100
# 39             Energia               84  Entre 50 e 100
# 40           Alimentos               64  Entre 50 e 100
# 41              Varejo               64  Entre 50 e 100
# 42               Banco               78  Entre 50 e 100
# 43               Banco               78  Entre 50 e 100
# 44          Siderurgia              121     Mais de 100
# 45             Energia                8     Menos de 50
# 46             Energia               67  Entre 50 e 100
# 47           Logística               57  Entre 50 e 100

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['Variacao_rs'].sum().reset_index()
df_analise_segmento
# Out:
#               Segmento   Variacao_rs
# 0            Alimentos  4.078337e+08
# 1              Aviação  6.545221e+07
# 2                Banco  4.636680e+09
# 3           Construção  3.752587e+07
# 4             Educação  7.229584e+07
# 5              Energia  1.209822e+09
# 6              Holding  4.160922e+08
# 7          Imobiliário  1.806845e+07
# 8            Logística  2.339027e+08
# 9   Meios de Pagamento  4.365768e+07
# 10           Mineração  4.940443e+09
# 11                Moda  4.102179e+07
# 12    Papel e Celulose  7.229463e+08
# 13            Petróleo  1.133648e+10
# 14             Química  6.905432e+07
# 15               Saúde  4.539179e+08
# 16    Shopping Centers  1.177327e+08
# 17          Siderurgia  4.899359e+08
# 18          Tecnologia  1.559889e+07
# 19    Telecomunicações  2.929381e+08
# 20              Varejo  2.371870e+08

# %%
df_analise_saldo = df_principal.groupby('Resultado')['Variacao_rs'].sum().reset_index()
df_analise_saldo
# Out:
#   Resultado   Variacao_rs
# 0    Desceu -6.891816e+09
# 1   Estável  0.000000e+00
# 2     Subiu  2.585859e+10

# %%
fig = px.bar(df_analise_saldo, x='Resultado', y='Variacao_rs', text='Variacao_rs', title='Variação Reais por Resultado')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ba818f36-4c0c-4cfd-aac0-72a19a6dc410" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba818f36-4c0c-4cfd-aac0-72a19a6dc410")) {                    Plotly.newPlot(                        "ba818f36-4c0c-4cfd-aac0-72a19a6dc410",                        [{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[-6891816486.985515,0.0,25858590641.34758],"textposition":"auto","x":["Desceu","Est\u00e1vel","Subiu"],"xaxis":"x","y":[-6891816486.985515,0.0,25858590641.34758],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar" ...

# %%
fig = px.pie(df_analise_segmento, values='Variacao_rs', names='Segmento', title='Variação Reais por Segmento')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4f0e5836-ab3c-4b62-b65d-acca03573a6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f0e5836-ab3c-4b62-b65d-acca03573a6f")) {                    Plotly.newPlot(                        "4f0e5836-ab3c-4b62-b65d-acca03573a6f",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Segmento=%{label}\u003cbr\u003eVariacao_rs=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Alimentos","Avia\u00e7\u00e3o","Banco","Constru\u00e7\u00e3o","Educa\u00e7\u00e3o","Energia","Holding","Imobili\u00e1rio","Log\u00edstica","Meios de Pagamento","Minera\u00e7\u00e3o","Moda","Papel e Celulose","Petr\u00f3leo","Qu\u00edmica","Sa\u00fade","Shopping Centers","Siderurgia","Tecnologia","Telecomunica\u00e7\u00f5es","Varejo"],"legendgroup":"","name":"","showlegend":true,"values":[407833683.0924499,65452205.552800186,4636679965.247721,37525872.37728388,72295838.98616095,1209821623.5672965,416092244.423763,18068446.60998324,233902674.79257408,43657683.37554085,4940442965.550434,41021792.09077153,722946282.7090385,11336484517.004236,69054317.63603853,453917907.01324,117732680.0784251,489935930.9283229,15598886.650556229,292938114.42357796,237187009.23736662],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"out ...

# %%
df_analise_idade = df_principal.groupby('Cat_idade')['Variacao_rs'].sum().reset_index()
df_analise_idade
# Out:
#         Cat_idade   Variacao_rs
# 0  Entre 50 e 100  1.679004e+10
# 1     Mais de 100 -2.024083e+08
# 2     Menos de 50  2.379139e+09

# %%
fig = px.bar(df_analise_idade, x='Cat_idade', y='Variacao_rs', text='Variacao_rs', title='Variação Reais por Faixa Etária')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="774ef81e-11df-4bda-b1bf-845c1de0b695" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("774ef81e-11df-4bda-b1bf-845c1de0b695")) {                    Plotly.newPlot(                        "774ef81e-11df-4bda-b1bf-845c1de0b695",                        [{"alignmentgroup":"True","hovertemplate":"Cat_idade=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[16790043304.010279,-202408309.86218917,2379139160.213975],"textposition":"auto","x":["Entre 50 e 100","Mais de 100","Menos de 50"],"xaxis":"x","y":[16790043304.010279,-202408309.86218917,2379139160.213975],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"ove ...
